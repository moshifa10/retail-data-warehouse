# %%
import pandas as pd

df = pd.read_csv("data/raw/customers.csv")

df
# Out:
#   customer_id customer_name              email          city
# 0        C001       Njabulo  njabulo@gmail.com  Johannesburg
# 1        C002        Ayanda   ayanda@gmail.com      Pretoria
# 2        C003         Sipho    sipho@gmail.com        Durban
# 3        C004        Lerato   lerato@gmail.com     Cape Town
# 4        C005         Thabo    thabo@gmail.com  Bloemfontein
# 5        C006        Zanele   zanele@gmail.com     Polokwane
# 6        C007         Peter    peter@gmail.com     Nelspruit
# 7        C008         Linda    linda@gmail.com     Kimberley
# 8        C009          John     john@gmail.com    Rustenburg
# 9        C010         Sarah    sarah@gmail.com  Johannesburg

# %%
df.loc[df["customer_id"] == "C001"]
df.iloc[6]
# Out:
# customer_id                 C007
# customer_name              Peter
# email            peter@gmail.com
# city                   Nelspruit
# Name: 6, dtype: str
